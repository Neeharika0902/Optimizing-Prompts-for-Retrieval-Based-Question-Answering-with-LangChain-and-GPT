# %% [markdown]
# In this code, the chunk size is fixed after finding the best from testing in part1 and the different prompts are testing and prompt 8 was found to be optimal after checking the ROUGE score.

# %% [markdown]
# ##Imports

# %%
# Install necessary libraries
# !pip install langchain langchain-openai langchain-core langchain-community
# !pip install faiss-cpu
# !pip install PyPDF2
# !pip install openai
# !pip install rouge-score
# !pip install python-dotenv
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.9)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (0.2.11)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.10/dist-packages (0.3.21)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.9)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.9)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.10.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (1.57.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.66.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.9.0.post1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.57.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Collecting openai
#   Downloading openai-1.57.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Downloading openai-1.57.0-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 24.1 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.5
#     Uninstalling openai-1.54.5:
#       Successfully uninstalled openai-1.54.5
# Successfully installed openai-1.57.0

# %%
# !pip install httpx==0.27.2 --force-reinstall
# Out:
# Collecting httpx==0.27.2
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx==0.27.2)
#   Downloading anyio-4.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi (from httpx==0.27.2)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx==0.27.2)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx==0.27.2)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting sniffio (from httpx==0.27.2)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx==0.27.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx==0.27.2)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting typing_extensions>=4.5 (from anyio->httpx==0.27.2)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.8 MB/s eta 0:00:00
# Downloading anyio-4.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.7 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.8 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 14.2 MB/s eta 0:00:00
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing_extensions, sniffio, idna, h11, exceptiongroup, certifi, httpcore, anyio, httpx
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.2
#     Uninstalling exceptiongroup-1.2.2:
#       Successfully uninstalled exceptiongroup-1.2.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.8.30
#     Uninstalling certifi-2024.8.30:
#       Successfully uninstalled certifi-2024.8.30
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.0
#     Uninstalling httpx-0.28.0:
#       Successfully uninstalled httpx-0.28.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.7.0 which is incompatible.
# Successfully installed anyio-4.7.0 certifi-2024.8.30 exceptiongroup-1.2.2 h11-0.14.0 httpcore-1.0.7 httpx-0.27.2 idna-3.10 sniffio-1.3.1 typing_extensions-4.12.2

# %%
# Import libraries
import os
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from rouge_score import rouge_scorer
import json
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.question_answering import load_qa_chain

# %% [markdown]
# ##Code

# %%
# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("API key not found. Ensure the .env file is correctly set up.")

os.environ["OPENAI_API_KEY"] = api_key

# %%
# Define function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    reader = PdfReader(pdf_path)
    all_text = ""
    for page in reader.pages:
        all_text += page.extract_text() + "\n"
    return all_text

# Define function to split text into chunks using LangChain Text Splitter
def split_text_into_chunks(text, chunk_size=8000, chunk_overlap=100):
    """Split text into smaller chunks using LangChain RecursiveCharacterTextSplitter."""
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", " ", ""]
    )
    chunks = splitter.split_text(text)
    return chunks

# Define function to create FAISS index
def create_faiss_index(text_chunks, embedding_model):
    """Create a FAISS index for document retrieval."""
    index = FAISS.from_texts(text_chunks, embedding_model)
    return index

# Load PDF and create text chunks
pdf_path = "/content/Part3_knowledge base.pdf"
raw_text = extract_text_from_pdf(pdf_path)
text_chunks = split_text_into_chunks(raw_text)

# Initialize embedding model and FAISS index
embedding_model = OpenAIEmbeddings()
faiss_index = create_faiss_index(text_chunks, embedding_model)

# Initialize retriever and chat model
retriever = faiss_index.as_retriever()
chat_model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
ground_truth = [
    {
        "question": "How did Meta’s workforce change by the end of 2023?",
        "answer": "By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022."
    },
    {
        "question": "What is the report quarter, and when did it end?",
        "answer": "The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023."
    },
    {
        "question": "What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?",
        "answer": "Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted)."
    },
    {
        "question": "How much did Meta spend on restructuring for the whole year and Q4?",
        "answer": "Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023."
    },
    {
        "question": "What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?",
        "answer": "In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%."
    },
    {
        "question": "What’s the revenue outlook for Q1 2024?",
        "answer": "Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion."
    },
    {
        "question": "What were Meta’s total costs and expenses for Q4 and the full year 2023?",
        "answer": "Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023."
    },
    {
        "question": "How much cash and marketable securities did Meta have on hand as of December 31, 2023?",
        "answer": "Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023."
    },
    {
        "question": "What were the main areas Meta invested in during 2023?",
        "answer": "Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development."
    },
    {
        "question": "How did the Family of Apps and Reality Labs perform in Q4 2023?",
        "answer": "In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion."
    },
    {
        "question": "How much free cash flow did Meta generate in Q4 and the full year 2023?",
        "answer": "Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023."
    },
    {
        "question": "Did Meta make any changes to its stock repurchase program or dividends for 2024?",
        "answer": "Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024."
    },
    {
        "question": "What risks did Meta highlight for 2024?",
        "answer": "Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments."
    },
    {
        "question": "What drove Meta’s revenue growth in Q4 2023?",
        "answer": "Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad."
    },
    {
        "question": "How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?",
        "answer": "Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses."
    }
]

# %%
# Initialize storage for evaluation results
evaluation_results_summary = []
evaluation_results_detailed = {}

# Function to evaluate the RAG system with a custom prompt, compute averages, and save/display results
def evaluate_rag_with_prompt(chat_model, retriever, ground_truth, prompt_template, prompt_name):
    from rouge_score import rouge_scorer
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

    # Define a PromptTemplate with the provided template
    prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

    # Load the QA chain
    qa_chain = load_qa_chain(
        llm=chat_model,
        chain_type="stuff",
        prompt=prompt
    )

    # Define the RetrievalQAWithSourcesChain
    retrieval_chain = RetrievalQAWithSourcesChain(
        retriever=retriever,
        combine_documents_chain=qa_chain
    )

    results = []

    for pair in ground_truth:
        # Run the retrieval chain with the question
        response = retrieval_chain({"question": pair["question"]})

        # Extract the predicted answer from the response
        predicted_answer = response.get("answer", "I don't know")

        # Compute ROUGE scores
        scores = scorer.score(pair["answer"], predicted_answer)
        results.append({
            "question": pair["question"],
            "ground_truth": pair["answer"],
            "predicted_answer": predicted_answer,
            "rouge1": scores['rouge1'].fmeasure,
            "rouge2": scores['rouge2'].fmeasure,
            "rougeL": scores['rougeL'].fmeasure,
        })

    # Compute average ROUGE scores
    def compute_average_rouge(evaluation_results):
        """Compute the average ROUGE-1, ROUGE-2, and ROUGE-L scores."""
        rouge1_total = 0
        rouge2_total = 0
        rougeL_total = 0
        count = len(evaluation_results)

        for result in evaluation_results:
            rouge1_total += result["rouge1"]
            rouge2_total += result["rouge2"]
            rougeL_total += result["rougeL"]

        avg_rouge1 = rouge1_total / count
        avg_rouge2 = rouge2_total / count
        avg_rougeL = rougeL_total / count

        return {"avg_rouge1": avg_rouge1, "avg_rouge2": avg_rouge2, "avg_rougeL": avg_rougeL}

    # Compute averages
    average_scores = compute_average_rouge(results)

    # Append results to the global storage variables
    global evaluation_results_summary, evaluation_results_detailed
    evaluation_results_summary.append({
        "Prompt Name": prompt_name,  # Use the provided prompt_name for labeling
        "Average ROUGE-1": average_scores["avg_rouge1"],
        "Average ROUGE-2": average_scores["avg_rouge2"],
        "Average ROUGE-L": average_scores["avg_rougeL"],
    })

    evaluation_results_detailed[prompt_name] = {
        "ROUGE-1": [res["rouge1"] for res in results],
        "ROUGE-2": [res["rouge2"] for res in results],
        "ROUGE-L": [res["rougeL"] for res in results],
    }

    # Display individual results
    print("Individual Results:")
    for result in results:
        print(f"Question: {result['question']}")
        print(f"Ground Truth: {result['ground_truth']}")
        print(f"Predicted Answer: {result['predicted_answer']}")
        print(f"ROUGE-1: {result['rouge1']}, ROUGE-2: {result['rouge2']}, ROUGE-L: {result['rougeL']}\n")

    # Display average ROUGE scores
    print("Average ROUGE Scores:")
    print(f"ROUGE-1: {average_scores['avg_rouge1']:.4f}")
    print(f"ROUGE-2: {average_scores['avg_rouge2']:.4f}")
    print(f"ROUGE-L: {average_scores['avg_rougeL']:.4f}")

    return {"results": results, "average_scores": average_scores}

# %% [markdown]
# ##Prompt Testing

# %% [markdown]
# ###prompt1

# %%
# Define your prompt
prompt1 = """
Use the context below to answer the question. If the answer cannot be found in the context, say "I don't know."

Context: {context}
Question: {question}
Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt1,
    prompt_name="Prompt 1"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's workforce decreased by 22% by the end of 2023, with a headcount of 67,317 employees.
# ROUGE-1: 0.5106382978723404, ROUGE-2: 0.26666666666666666, ROUGE-L: 0.3404255319148936
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for the quarter ended December 31, 2023, were as follows:
# - Revenue: $40,111 million
# - Gross Margin: Total costs and expenses were $23,727 million, resulting in a gross margin of $16,384 million
# - Operating Expenses: Total operating expenses were $23,727 million
# - Operating Margin: The operating margin was 41%
# - Net Income: $14,017 million
# - Earnings Per Share (EPS): Diluted EPS was $5.33
# ROUGE-1: 0.4375, ROUGE-2: 0.21276595744680848, ROUGE-L: 0.39583333333333337
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year, Meta spent $3.45 billion on restructuring, and for Q4, they spent $1.15 billion on restructuring.
# ROUGE-1: 0.7317073170731706, ROUGE-2: 0.46153846153846156, ROUGE-L: 0.3414634146341463
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, and the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7422680412371133, ROUGE-2: 0.631578947368421, ROUGE-L: 0.7422680412371133
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: For the fourth quarter of 2023, Meta's total costs and expenses were $23.73 billion. For the full year 2023, the total costs and expenses were $88.15 billion.
# ROUGE-1: 0.8076923076923077, ROUGE-2: 0.64, ROUGE-L: 0.6153846153846153
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: As of December 31, 2023, Meta had cash and cash equivalents of $41,862 million and marketable securities of $23,541 million, totaling $65,403 million.
# ROUGE-1: 0.6511627906976744, ROUGE-2: 0.39024390243902435, ROUGE-L: 0.41860465116279066
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in several areas during 2023, including infrastructure-related costs, payroll expenses, and operating losses for Reality Labs. They also made capital investments in servers, AI hardware, and data centers. Additionally, they focused on product development efforts in augmented reality/virtual reality and scaling their ecosystem.
# ROUGE-1: 0.46376811594202894, ROUGE-2: 0.1492537313432836, ROUGE-L: 0.2608695652173913
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps had a revenue of $39.04 billion and income from operations of $21.03 billion. Reality Labs had a revenue of $1.07 billion and a loss from operations of $4.65 billion.
# ROUGE-1: 0.7671232876712328, ROUGE-2: 0.4507042253521127, ROUGE-L: 0.7123287671232875
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: Meta generated $11.50 billion in free cash flow for the fourth quarter of 2023 and $43.01 billion for the full year 2023.
# ROUGE-1: 0.888888888888889, ROUGE-2: 0.8372093023255814, ROUGE-L: 0.888888888888889
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share of outstanding common stock for 2024.
# ROUGE-1: 0.8, ROUGE-2: 0.6415094339622641, ROUGE-L: 0.7636363636363636
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including the impact of macroeconomic conditions on their business and financial results, their ability to retain or increase users and engagement levels, reliance on advertising revenue, changes to third-party policies affecting advertising practices, risks associated with new products and initiatives, emphasis on community growth over short-term financial results, privacy, safety, security, and content review efforts, competition, government actions restricting access to products, litigation and government inquiries, privacy, legislative, and regulatory concerns, risks associated with acquisitions, security breaches, managing scale and operations, and market conditions affecting dividend payments.
# ROUGE-1: 0.21487603305785127, ROUGE-2: 0.01680672268907563, ROUGE-L: 0.18181818181818182
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: The revenue growth in Q4 2023 for Meta was primarily driven by an increase in ad impressions delivered across their Family of Apps, which increased by 21% year-over-year. Additionally, the average price per ad also increased by 2% year-over-year in the fourth quarter of 2023.
# ROUGE-1: 0.5753424657534246, ROUGE-2: 0.3661971830985915, ROUGE-L: 0.49315068493150693
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs had a challenging year in 2023, with a loss of $16.12 billion for the full year. In 2024, Meta expects operating losses for Reality Labs to increase meaningfully year-over-year due to ongoing product development efforts in augmented reality/virtual reality and investments to further scale the ecosystem. They anticipate that their ambitious long-term AI research and product development efforts will require growing infrastructure investments beyond 2024.
# ROUGE-1: 0.4727272727272728, ROUGE-2: 0.20370370370370372, ROUGE-L: 0.34545454545454546
#
# Average ROUGE Scores:
# ROUGE-1: 0.6511
# ROUGE-2: 0.4427
# ROUGE-L: 0.5393

# %% [markdown]
# ###prompt2

# %%
# Define your prompt
prompt2 = """
You are a data analyst assisting with financial reports. Use the context below to answer the question with specific and concise details.
If the answer cannot be found in the context, respond with "I don't know."

Context:
{context}

Question:
{question}

Answer:
"""
# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt2,
    prompt_name="Prompt 2"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's headcount was 67,317 as of December 31, 2023, which represented a decrease of 22% year-over-year.
# ROUGE-1: 0.32653061224489793, ROUGE-2: 0.0425531914893617, ROUGE-L: 0.20408163265306123
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the Fourth Quarter of 2023, and it ended on December 31, 2023.
# ROUGE-1: 0.875, ROUGE-2: 0.8000000000000002, ROUGE-L: 0.875
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for this quarter are as follows:
# - Revenue: $40.11 billion
# - Gross margin: $16,384 million
# - Operating expenses: $23,727 million
# - Operating margin: 41%
# - Net income: $14,017 million
# - EPS: $5.33
# ROUGE-1: 0.625, ROUGE-2: 0.4838709677419355, ROUGE-L: 0.625
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year, Meta spent $3.45 billion on restructuring, and for Q4, they spent $1.15 billion on restructuring.
# ROUGE-1: 0.7317073170731706, ROUGE-2: 0.46153846153846156, ROUGE-L: 0.3414634146341463
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, and the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7422680412371133, ROUGE-2: 0.631578947368421, ROUGE-L: 0.7422680412371133
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: For the fourth quarter of 2023, Meta's total costs and expenses were $23.73 billion. For the full year 2023, the total costs and expenses were $88.15 billion.
# ROUGE-1: 0.8076923076923077, ROUGE-2: 0.64, ROUGE-L: 0.6153846153846153
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: Meta had $65.40 billion in cash, cash equivalents, and marketable securities on hand as of December 31, 2023.
# ROUGE-1: 0.9444444444444444, ROUGE-2: 0.8823529411764706, ROUGE-L: 0.9444444444444444
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in infrastructure-related costs, payroll expenses, and operating losses for Reality Labs in 2023. They also made capital expenditures in servers, AI and non-AI hardware, and data centers.
# ROUGE-1: 0.4905660377358491, ROUGE-2: 0.19607843137254902, ROUGE-L: 0.2641509433962264
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps segment had a total revenue of $39.04 billion and income from operations of $21.03 billion. On the other hand, the Reality Labs segment had a total revenue of $1.07 billion but incurred a loss from operations of $4.65 billion.
# ROUGE-1: 0.6746987951807228, ROUGE-2: 0.3703703703703704, ROUGE-L: 0.6265060240963856
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: In Q4 2023, Meta generated $11.50 billion in free cash flow. For the full year 2023, Meta generated $43.01 billion in free cash flow.
# ROUGE-1: 0.8085106382978723, ROUGE-2: 0.7111111111111111, ROUGE-L: 0.5957446808510638
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share of outstanding common stock for 2024.
# ROUGE-1: 0.8, ROUGE-2: 0.6415094339622641, ROUGE-L: 0.7636363636363636
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including the impact of macroeconomic conditions, the ability to retain or increase users and engagement levels, reliance on advertising revenue, changes to third-party policies affecting advertising practices, risks associated with new products and initiatives, emphasis on community growth over short-term financial results, privacy, safety, security, and content review efforts, competition, government actions restricting access to products, litigation and government inquiries, privacy, legislative, and regulatory concerns, risks associated with acquisitions, security breaches, managing scale and operations, and market conditions affecting dividend payments.
# ROUGE-1: 0.22608695652173913, ROUGE-2: 0.017699115044247787, ROUGE-L: 0.19130434782608693
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: The revenue growth in Q4 2023 for Meta was primarily driven by an increase in ad impressions delivered across their Family of Apps, which increased by 21% year-over-year. Additionally, the average price per ad increased by 2% year-over-year in the fourth quarter of 2023.
# ROUGE-1: 0.5833333333333334, ROUGE-2: 0.37142857142857144, ROUGE-L: 0.5
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs had a challenging performance in 2023, with a loss of $16.12 billion for the full year. Meta plans to continue investing in Reality Labs in 2024, expecting operating losses to increase significantly due to ongoing product development efforts in augmented reality/virtual reality and investments to scale the ecosystem further. They anticipate capital expenditures for 2024 to be in the range of $30-37 billion, with a focus on investments in servers, including AI and non-AI hardware, and data centers to support future research and product development in AI beyond 2024.
# ROUGE-1: 0.4360902255639098, ROUGE-2: 0.24427480916030533, ROUGE-L: 0.3308270676691729
#
# Average ROUGE Scores:
# ROUGE-1: 0.6581
# ROUGE-2: 0.4693
# ROUGE-L: 0.5537

# %% [markdown]
# ###prompt3

# %%
prompt3 = """
You are a financial analysis assistant. Use the context below to answer the question accurately and concisely, focusing on specific data points and numerical details where applicable.

If the answer cannot be found in the context, respond with "I don't know." Avoid making assumptions or including information not present in the context.

Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt3,
    prompt_name="Prompt 3"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's headcount was 67,317 as of December 31, 2023, which represented a decrease of 22% year-over-year.
# ROUGE-1: 0.32653061224489793, ROUGE-2: 0.0425531914893617, ROUGE-L: 0.20408163265306123
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for the quarter ended December 31, 2023, for Meta Platforms, Inc. were as follows:
# - Revenue: $40.11 billion
# - Gross Margin (Operating Margin): 41%
# - Operating Expenses: $23.73 billion
# - Net Income: $14.02 billion
# - Earnings Per Share (EPS): $5.33
# ROUGE-1: 0.6944444444444445, ROUGE-2: 0.5142857142857143, ROUGE-L: 0.6111111111111112
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year of 2023, Meta spent $3.45 billion on restructuring. In Q4 of 2023, Meta spent $1.15 billion on restructuring.
# ROUGE-1: 0.8181818181818182, ROUGE-2: 0.6190476190476191, ROUGE-L: 0.4090909090909091
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, but the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7422680412371133, ROUGE-2: 0.631578947368421, ROUGE-L: 0.7422680412371133
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: For the fourth quarter of 2023, Meta's total costs and expenses were $23.73 billion. For the full year 2023, their total costs and expenses were $88.15 billion.
# ROUGE-1: 0.8076923076923077, ROUGE-2: 0.64, ROUGE-L: 0.6153846153846153
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: Meta had $65.40 billion in cash, cash equivalents, and marketable securities on hand as of December 31, 2023.
# ROUGE-1: 0.9444444444444444, ROUGE-2: 0.8823529411764706, ROUGE-L: 0.9444444444444444
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in several key areas during 2023, including capital expenditures, share repurchases, and acquisitions of businesses and intangible assets. They also focused on infrastructure-related costs, payroll expenses, and operating losses for Reality Labs to support their product development efforts in augmented reality/virtual reality. Additionally, they made investments in servers, AI hardware, and data centers to support their evolving AI research and product development efforts.
# ROUGE-1: 0.3595505617977528, ROUGE-2: 0.11494252873563218, ROUGE-L: 0.20224719101123595
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps segment had a revenue of $39.04 billion and an income from operations of $21.03 billion. On the other hand, the Reality Labs segment had a revenue of $1.07 billion and a loss from operations of $4.65 billion.
# ROUGE-1: 0.7160493827160493, ROUGE-2: 0.379746835443038, ROUGE-L: 0.6419753086419753
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: Meta generated $11.50 billion in free cash flow for the fourth quarter of 2023 and $43.01 billion for the full year 2023.
# ROUGE-1: 0.888888888888889, ROUGE-2: 0.8372093023255814, ROUGE-L: 0.888888888888889
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share of outstanding common stock for 2024.
# ROUGE-1: 0.8, ROUGE-2: 0.6415094339622641, ROUGE-L: 0.7636363636363636
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including higher infrastructure-related costs, increased depreciation expenses, higher operating costs from running a larger infrastructure footprint, growth in payroll expenses, operating losses in Reality Labs due to ongoing product development efforts in augmented reality/virtual reality, and potential impacts from the active regulatory landscape, including legal and regulatory headwinds in the EU and the U.S. that could significantly impact their business and financial results.
# ROUGE-1: 0.40816326530612246, ROUGE-2: 0.16666666666666666, ROUGE-L: 0.2448979591836735
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: The revenue growth in Q4 2023 for Meta was primarily driven by a 25% increase in advertising revenue, which amounted to $38.71 billion. Additionally, other revenue sources contributed $334 million, resulting in a total revenue of $40.11 billion for the quarter.
# ROUGE-1: 0.41791044776119407, ROUGE-2: 0.2153846153846154, ROUGE-L: 0.3880597014925373
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs had a challenging performance in 2023, with a loss of $16.12 billion for the full year. Meta plans to continue investing in Reality Labs in 2024, expecting operating losses to increase meaningfully due to ongoing product development efforts in augmented reality/virtual reality and investments to further scale the ecosystem. Additionally, Meta anticipates growing infrastructure investments beyond 2024 to support long-term AI research and product development efforts.
# ROUGE-1: 0.5137614678899082, ROUGE-2: 0.28037383177570097, ROUGE-L: 0.40366972477064217
#
# Average ROUGE Scores:
# ROUGE-1: 0.6761
# ROUGE-2: 0.4892
# ROUGE-L: 0.5766

# %% [markdown]
# ###prompt4

# %%
prompt4 = """
You are a financial data analyst tasked with providing precise, accurate, and concise answers using the context provided below.

- Include numerical details wherever possible, especially for increases, decreases, percentages, and calculations derived from the information provided.
- If the exact information is not present, use available data to calculate or infer the answer to the best of your ability.
- If no relevant data is available, respond with "I don't know."
- Focus on specific data points, dates, and numerical values.

Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt4,
    prompt_name="Prompt 4"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's headcount was 67,317 as of December 31, 2023, which represented a decrease of 22% year-over-year.
# ROUGE-1: 0.32653061224489793, ROUGE-2: 0.0425531914893617, ROUGE-L: 0.20408163265306123
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: Key financial highlights for the quarter ended December 31, 2023, for Meta Platforms, Inc. include:
#
# 1. Revenue: $40.11 billion, representing a 25% increase year-over-year.
# 2. Gross Margin: Total costs and expenses were $23.73 billion, resulting in a gross margin of 41%.
# 3. Operating Expenses: Operating expenses were broken down as follows:
#    - Research and development: $10.52 billion
#    - Marketing and sales: $3.23 billion
#    - General and administrative: $2.29 billion
# 4. Operating Margin: Operating income was $16.38 billion, with an operating margin of 41%.
# 5. Net Income: Net income was $14.02 billion, showing a significant increase of 201% year-over-year.
# 6. Earnings Per Share (EPS): Diluted EPS was $5.33, reflecting a 203% increase compared to the same quarter last year.
# ROUGE-1: 0.358974358974359, ROUGE-2: 0.1818181818181818, ROUGE-L: 0.32051282051282054
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year ended December 31, 2023, Meta spent a total of $3.45 billion on restructuring. In Q4 alone, the restructuring charges included in costs and expenses were $1.15 billion.
# ROUGE-1: 0.679245283018868, ROUGE-2: 0.39215686274509803, ROUGE-L: 0.339622641509434
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, while the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7628865979381444, ROUGE-2: 0.6526315789473685, ROUGE-L: 0.7628865979381444
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: Meta's total costs and expenses for the fourth quarter of 2023 were $23.73 billion, representing an 8% decrease compared to the same period in 2022. For the full year 2023, the total costs and expenses were $88.15 billion, showing a 1% increase compared to 2022.
# ROUGE-1: 0.6, ROUGE-2: 0.4411764705882353, ROUGE-L: 0.4571428571428572
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: Meta had $65.40 billion in cash, cash equivalents, and marketable securities on hand as of December 31, 2023.
# ROUGE-1: 0.9444444444444444, ROUGE-2: 0.8823529411764706, ROUGE-L: 0.9444444444444444
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in several key areas during 2023, including:
# 1. Capital expenditures, including principal payments on finance leases, totaling $28.10 billion for the full year.
# 2. Share repurchases of $20.03 billion for the full year.
# 3. Research and development expenses of $38.48 billion for the full year.
# 4. Operating costs related to running a larger infrastructure footprint.
# 5. Ongoing product development efforts in augmented reality/virtual reality within Reality Labs.
# 6. Investments in servers, including AI and non-AI hardware, and data centers.
# 7. Infrastructure-related costs, including increased depreciation expenses.
# 8. Payroll expenses to support hiring and talent acquisition in priority areas.
# 9. Continued investments in AI research and product development.
# 10. Long-term debt of $18.39 billion as of December 31, 2023.
# ROUGE-1: 0.22666666666666668, ROUGE-2: 0.06756756756756757, ROUGE-L: 0.14666666666666667
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps segment generated revenue of $39.04 billion, with income from operations of $21.03 billion. This segment showed strong performance. On the other hand, Reality Labs reported revenue of $1.07 billion but incurred a loss from operations of $4.65 billion, indicating challenges in that segment.
# ROUGE-1: 0.6666666666666667, ROUGE-2: 0.3764705882352941, ROUGE-L: 0.6206896551724137
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: Meta generated $11.50 billion in free cash flow for the fourth quarter of 2023 and $43.01 billion for the full year 2023.
# ROUGE-1: 0.888888888888889, ROUGE-2: 0.8372093023255814, ROUGE-L: 0.888888888888889
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share of outstanding common stock for 2024.
# ROUGE-1: 0.8, ROUGE-2: 0.6415094339622641, ROUGE-L: 0.7636363636363636
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including the impact of macroeconomic conditions on their business and financial results, the ability to retain or increase users and engagement levels, reliance on advertising revenue, dependency on data signals and mobile operating systems, changes to third-party policies affecting advertising practices, risks associated with new products and initiatives, emphasis on community growth over short-term financial results, privacy, safety, security, and content review efforts, competition, government actions restricting access to products, litigation and government inquiries, privacy, legislative, and regulatory concerns, risks associated with acquisitions, security breaches, managing scale and operations, and market conditions affecting dividend payments.
# ROUGE-1: 0.21705426356589144, ROUGE-2: 0.015748031496062992, ROUGE-L: 0.17054263565891473
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: The revenue growth in Q4 2023 for Meta was primarily driven by an increase in ad impressions and the average price per ad. Ad impressions delivered across their Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. Additionally, revenue growth was also impacted by the overall increase in the number of active users on their platforms.
# ROUGE-1: 0.4782608695652174, ROUGE-2: 0.33333333333333337, ROUGE-L: 0.41304347826086957
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs had a challenging performance in 2023, with a loss of $16.12 billion for the full year. This was an improvement from the previous year's loss of $13.72 billion. Meta plans to continue investing in Reality Labs in 2024, expecting operating losses to increase meaningfully due to ongoing product development efforts in augmented reality/virtual reality and investments to further scale the ecosystem. They anticipate the need for growing infrastructure investments beyond 2024 to support their ambitious long-term AI research and product development efforts.
# ROUGE-1: 0.4566929133858268, ROUGE-2: 0.23999999999999996, ROUGE-L: 0.3464566929133858
#
# Average ROUGE Scores:
# ROUGE-1: 0.6073
# ROUGE-2: 0.4318
# ROUGE-L: 0.5312

# %% [markdown]
# ###prompt5

# %%
prompt5 = """
You are a financial data analyst assisting with financial reports. Use the context provided below to answer the question accurately, concisely, and in detail.

- Include specific numerical details wherever possible, especially for increases, decreases, percentages, and calculated values derived from the context.
- Format your answers to directly address the question in the simplest terms, matching the style and structure of the examples provided.
- Avoid over-explaining or including irrelevant information.
- If the context does not contain the required information, respond with "I don't know."

Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt5,
    prompt_name="Prompt 5"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's workforce decreased by 22% year-over-year, with a headcount of 67,317 as of December 31, 2023.
# ROUGE-1: 0.3673469387755102, ROUGE-2: 0.0425531914893617, ROUGE-L: 0.20408163265306123
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for this quarter are as follows:
# - Revenue: $40.11 billion, representing a 25% increase year-over-year.
# - Gross Margin: Total costs and expenses were $23.73 billion, resulting in a gross margin of 41%.
# - Operating Expenses: Operating expenses included cost of revenue, research and development, marketing and sales, and general and administrative expenses totaling $23.73 billion.
# - Operating Margin: The operating margin was 41%.
# - Net Income: Net income was $14.02 billion, showing a significant increase of 201% year-over-year.
# - Earnings Per Share (EPS): Diluted EPS was $5.33, reflecting a 203% increase year-over-year.
# ROUGE-1: 0.41538461538461535, ROUGE-2: 0.25, ROUGE-L: 0.36923076923076914
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year of 2023, Meta spent a total of $3.45 billion on restructuring, which includes $2.51 billion for the three months ended December 31, 2023. Specifically, the breakdown of restructuring charges for the full year includes $1.10 billion for facilities consolidation, $41 million for severance and other personnel costs, and $7 million for data center assets. In the fourth quarter alone, Meta incurred $1.15 billion in restructuring charges, comprising $86 million for facilities consolidation, $41 million for severance and other personnel costs, and $7 million for data center assets.
# ROUGE-1: 0.3130434782608696, ROUGE-2: 0.19469026548672566, ROUGE-L: 0.1565217391304348
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, while the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, but the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7422680412371133, ROUGE-2: 0.6105263157894737, ROUGE-L: 0.7216494845360825
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: Meta's total costs and expenses for the fourth quarter of 2023 were $23.73 billion, representing an 8% decrease compared to the same period in 2022. For the full year 2023, the total costs and expenses amounted to $88.15 billion, showing a 1% increase compared to the previous year.
# ROUGE-1: 0.5753424657534247, ROUGE-2: 0.3943661971830986, ROUGE-L: 0.49315068493150693
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: As of December 31, 2023, Meta Platforms, Inc. had $41.86 billion in cash and cash equivalents and $23.54 billion in marketable securities, totaling $65.40 billion in cash and marketable securities on hand.
# ROUGE-1: 0.6538461538461539, ROUGE-2: 0.48, ROUGE-L: 0.3846153846153846
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in several key areas during 2023, including:
# 1. Capital expenditures: Meta spent $28.10 billion on capital expenditures, including principal payments on finance leases, to support its business operations.
# 2. Share repurchases: Meta repurchased $20.03 billion of its Class A common stock in 2023.
# 3. Research and development: Meta invested heavily in research and development, with expenses totaling $38.48 billion for the year.
# 4. Reality Labs: Despite incurring operating losses in Reality Labs, Meta continued to invest in product development efforts in augmented reality/virtual reality to further scale its ecosystem.
# 5. Infrastructure-related costs: Meta expected higher infrastructure-related costs in 2024, indicating ongoing investments in infrastructure to support its operations.
# 6. AI and metaverse efforts: Meta emphasized its ambitious long-term AI research and product development efforts, indicating continued investment in these areas for future growth and innovation.
# ROUGE-1: 0.1566265060240964, ROUGE-2: 0.060975609756097573, ROUGE-L: 0.12048192771084337
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps segment generated a revenue of $39.04 billion, an increase from $31.44 billion in Q4 2022. The segment also reported an income from operations of $21.03 billion, up from $10.68 billion in the same period last year. On the other hand, Reality Labs segment had a revenue of $1.07 billion, compared to $0.73 billion in Q4 2022. However, the segment incurred a loss from operations of $4.65 billion, slightly higher than the loss of $4.28 billion in Q4 2022.
# ROUGE-1: 0.4603174603174603, ROUGE-2: 0.25806451612903225, ROUGE-L: 0.4126984126984127
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: Meta generated $11.50 billion in free cash flow in the fourth quarter of 2023 and $43.01 billion for the full year 2023.
# ROUGE-1: 0.8444444444444444, ROUGE-2: 0.7906976744186046, ROUGE-L: 0.8444444444444444
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta made changes to its stock repurchase program and dividends for 2024. Meta's board of directors declared a cash dividend of $0.50 per share of outstanding common stock, payable on March 26, 2024, to stockholders of record as of February 22, 2024. Additionally, Meta announced a $50 billion increase in its share repurchase authorization. This indicates that Meta has initiated a quarterly dividend and increased its share repurchase program for 2024.
# ROUGE-1: 0.52, ROUGE-2: 0.4489795918367347, ROUGE-L: 0.3400000000000001
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including:
# 1. Impact of macroeconomic conditions on business and financial results, including geopolitical events.
# 2. Ability to retain or increase users and engagement levels.
# 3. Reliance on advertising revenue.
# 4. Dependency on data signals, mobile operating systems, networks, and standards not controlled by Meta.
# 5. Changes to third-party policies affecting advertising practices.
# 6. Risks associated with new products, changes to existing products, and metaverse efforts.
# 7. Emphasis on community growth and engagement over short-term financial results.
# 8. Privacy, safety, security, and content review efforts.
# 9. Competition.
# 10. Risks associated with government actions restricting access to products or impairing advertising sales in certain countries.
# 11. Litigation and government inquiries.
# 12. Privacy, legislative, and regulatory concerns or developments.
# 13. Risks associated with acquisitions.
# 14. Security breaches.
# 15. Ability to manage scale and geographically-dispersed operations.
# 16. Market conditions or other factors affecting dividend payments.
# ROUGE-1: 0.1590909090909091, ROUGE-2: 0.011494252873563218, ROUGE-L: 0.12500000000000003
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: Meta's revenue growth in Q4 2023 was primarily driven by a 25% year-over-year increase in advertising revenue, which amounted to $38.71 billion. Additionally, other revenue sources contributed $334 million, bringing the total revenue for the quarter to $40.11 billion. The growth in advertising revenue was fueled by a 21% increase in ad impressions across their Family of Apps and a 2% increase in the average price per ad. These factors combined to boost Meta's overall revenue for the quarter.
# ROUGE-1: 0.44036697247706424, ROUGE-2: 0.39252336448598124, ROUGE-L: 0.44036697247706424
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs, a segment of Meta Platforms, reported a loss from operations of $4.646 billion for the fourth quarter of 2023 and a loss of $16.120 billion for the full year 2023. This indicates a challenging performance for Reality Labs in 2023.
#
# Looking ahead to 2024, Meta expects operating losses for Reality Labs to increase significantly year-over-year due to ongoing product development efforts in augmented reality/virtual reality and investments to further scale the ecosystem. This suggests that Meta is committed to continuing its investments in Reality Labs despite the current losses, emphasizing its long-term vision for augmented and virtual reality technologies.
# ROUGE-1: 0.3862068965517241, ROUGE-2: 0.15384615384615383, ROUGE-L: 0.26206896551724135
#
# Average ROUGE Scores:
# ROUGE-1: 0.5158
# ROUGE-2: 0.3641
# ROUGE-L: 0.4309

# %% [markdown]
# ###prompt6

# %%
prompt6 = """
You are a financial data analyst tasked with answering questions about financial reports.

- Use only the information provided in the context to answer the question accurately and concisely.
- Include specific numerical details wherever applicable (e.g., percentages, increases, or decreases) and perform calculations based on the context.
- Avoid including extra points, tangential information, or assumptions that are not directly relevant to the question.
- Ensure the answer is formatted in a direct, single-paragraph response.
- If the context does not contain the required information, respond with "I don't know."

Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt6,
    prompt_name="Prompt 6"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: Meta's headcount was 67,317 as of December 31, 2023, which represented a decrease of 22% year-over-year.
# ROUGE-1: 0.32653061224489793, ROUGE-2: 0.0425531914893617, ROUGE-L: 0.20408163265306123
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for the quarter ended December 31, 2023, for Meta Platforms, Inc. were as follows:
# - Revenue: $40.11 billion, representing a 25% increase year-over-year.
# - Gross Margin: The cost of revenue was $7.70 billion, resulting in a gross margin of 19.2%.
# - Operating Expenses: Total operating expenses were $23.73 billion.
# - Operating Margin: Income from operations was $16.38 billion, with an operating margin of 41%.
# - Net Income: Net income was $14.02 billion, showing a significant increase of 201% year-over-year.
# - Earnings Per Share (EPS): Diluted EPS was $5.33, reflecting a 203% increase compared to the same quarter last year.
# ROUGE-1: 0.3795620437956204, ROUGE-2: 0.237037037037037, ROUGE-L: 0.3649635036496351
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year of 2023, Meta spent a total of $3.45 billion on restructuring, with $2.51 billion allocated for facilities consolidation, severance, and other personnel costs, and $938 million for data center assets. In Q4 of 2023 alone, Meta spent $1.15 billion on restructuring, with $1.10 billion allocated for facilities consolidation, severance, and other personnel costs, and $41 million for data center assets.
# ROUGE-1: 0.43181818181818177, ROUGE-2: 0.27906976744186046, ROUGE-L: 0.22727272727272727
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, ad impressions delivered across Meta's Family of Apps increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, while the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.7628865979381444, ROUGE-2: 0.6526315789473685, ROUGE-L: 0.7628865979381444
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion, assuming foreign currency is neutral to year-over-year total revenue growth based on current exchange rates.
# ROUGE-1: 0.5769230769230769, ROUGE-2: 0.36000000000000004, ROUGE-L: 0.46153846153846156
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: Meta's total costs and expenses for the fourth quarter of 2023 were $23.73 billion, representing an 8% decrease compared to the same period in 2022. For the full year 2023, the total costs and expenses amounted to $88.15 billion, showing a 1% increase compared to the previous year.
# ROUGE-1: 0.5753424657534247, ROUGE-2: 0.3943661971830986, ROUGE-L: 0.49315068493150693
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: As of December 31, 2023, Meta Platforms, Inc. had cash and cash equivalents totaling $41.862 billion and marketable securities amounting to $23.541 billion, resulting in a total of $65.403 billion in cash and marketable securities on hand.
# ROUGE-1: 0.5614035087719298, ROUGE-2: 0.32727272727272727, ROUGE-L: 0.31578947368421056
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in several key areas during 2023, including capital expenditures, share repurchases, and operating expenses. They spent $28.10 billion on capital expenditures, including principal payments on finance leases, to support their business operations. Additionally, they repurchased $20.03 billion of their Class A common stock and had $30.93 billion available for further repurchases. Operating expenses, including costs and expenses, totaled $88.15 billion for the full year, reflecting investments in research and development, marketing, and general administrative functions. These investments aimed to support their growth, innovation, and strategic priorities across their Family of Apps and Reality Labs segments.
# ROUGE-1: 0.16260162601626016, ROUGE-2: 0.03305785123966942, ROUGE-L: 0.13008130081300814
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps segment generated revenue of $39.04 billion, with income from operations of $21.03 billion. This segment showed strong performance. On the other hand, Reality Labs reported revenue of $1.07 billion but incurred a loss from operations of $4.65 billion, indicating a challenging performance for Reality Labs in the same quarter.
# ROUGE-1: 0.6236559139784946, ROUGE-2: 0.3516483516483517, ROUGE-L: 0.5806451612903226
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: Meta generated $11.50 billion in free cash flow in the fourth quarter of 2023 and $43.01 billion for the full year 2023.
# ROUGE-1: 0.8444444444444444, ROUGE-2: 0.7906976744186046, ROUGE-L: 0.8444444444444444
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta made changes to its stock repurchase program and dividends for 2024. The company announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share of outstanding common stock, payable on March 26, 2024, to stockholders of record as of February 22, 2024. These actions reflect Meta's commitment to returning value to its shareholders.
# ROUGE-1: 0.5652173913043478, ROUGE-2: 0.48888888888888893, ROUGE-L: 0.5434782608695652
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: Meta highlighted several risks for 2024, including the impact of macroeconomic conditions on their business and financial results, their ability to retain or increase users and engagement levels, reliance on advertising revenue, dependency on data signals and mobile operating systems, changes to third-party policies affecting advertising practices, risks associated with new products and initiatives, emphasis on community growth over short-term financial results, privacy, safety, security, and content review efforts, competition, government actions restricting access to products, litigation and government inquiries, privacy, legislative, and regulatory concerns, risks associated with acquisitions, security breaches, managing scale and geographically-dispersed operations, and market conditions affecting dividend payments. These risks could potentially impact Meta's business and financial performance in 2024.
# ROUGE-1: 0.20833333333333331, ROUGE-2: 0.014084507042253521, ROUGE-L: 0.15277777777777776
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: Meta's revenue growth in Q4 2023 was primarily driven by a 25% increase in advertising revenue, which amounted to $38.71 billion. Additionally, other revenue sources contributed $334 million, resulting in a total revenue of $40.11 billion for the quarter. The growth in ad impressions delivered across their Family of Apps by 21% year-over-year and a 2% increase in the average price per ad also played a significant role in driving the revenue growth.
# ROUGE-1: 0.47058823529411764, ROUGE-2: 0.38, ROUGE-L: 0.45098039215686275
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs, a segment of Meta Platforms, reported a loss from operations of $16.12 billion for the full year 2023, with a decrease in performance compared to the previous year. Looking ahead to 2024, Meta anticipates a meaningful increase in operating losses for Reality Labs due to ongoing product development efforts in augmented reality/virtual reality and investments to scale the ecosystem further. The company expects to continue its ambitious long-term AI research and product development efforts, requiring growing infrastructure investments beyond 2024. Additionally, Meta plans to increase capital expenditures in the range of $30-37 billion for 2024, primarily driven by investments in servers, including AI and non-AI hardware, and data centers to support future research and product development needs.
# ROUGE-1: 0.37037037037037035, ROUGE-2: 0.175, ROUGE-L: 0.23456790123456792
#
# Average ROUGE Scores:
# ROUGE-1: 0.5175
# ROUGE-2: 0.3569
# ROUGE-L: 0.4447

# %% [markdown]
# ###prompt7

# %%
prompt7 = """
You are a financial data analyst tasked with answering questions about financial reports.

- Use only the information provided in the context to answer the question accurately and concisely.
- Include specific numerical details wherever applicable (e.g., percentages, increases, or decreases) and perform calculations based on the context.
- Don't return special characters
- Avoid including extra points, tangential information, or assumptions that are not directly relevant to the question.
- Ensure the answer is formatted in a direct, single-paragraph response.
- If the context does not contain the required information, respond with "I don't know."

### Example Questions and Answers:
1. **Question**: How did Meta’s workforce change by the end of 2023?
   **Workforce Change Calculation**:
   - Step 1: Identify the old and new values. Old Value = 87,314 (2022 workforce), New Value = 67,317 (2023 workforce).
   - Step 2: Subtract the new value from the old value to find the difference: \( 87,314 - 67,317 = 19,997 \).
   - Step 3: Divide the difference by the old value to calculate the percentage change:
     \( \frac{{19,997}}{{87,314}} \approx 0.229 \).
   - Step 4: Multiply by 100 to convert to a percentage:
     \( 0.229 \times 100 = 22.9\% \).

   **Answer**: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.

2. **Question**: What is the report quarter, and when did it end?
   **Answer**: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.

### Your Task:
Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt7,
    prompt_name="Prompt 7"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: By the end of 2023, Meta's workforce was 67,317 employees, representing a 22% decrease compared to the previous year.
# ROUGE-1: 0.56, ROUGE-2: 0.375, ROUGE-L: 0.56
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, which ended on December 31, 2023.
# ROUGE-1: 0.9032258064516129, ROUGE-2: 0.8275862068965518, ROUGE-L: 0.9032258064516129
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for the quarter ended December 31, 2023, for Meta Platforms, Inc. were as follows: Revenue was $40.11 billion, representing a 25% increase year-over-year. The operating margin was 41%, showing a significant improvement from 20% in the previous year. Net income was $14.02 billion, a substantial increase of 201% compared to the same quarter last year. Earnings per share (EPS) stood at $5.33, reflecting a 203% increase year-over-year. Additionally, total costs and expenses were $23.73 billion, resulting in a gross margin of 68.2%. These highlights demonstrate strong financial performance and growth for Meta in the fourth quarter of 2023.
# ROUGE-1: 0.3571428571428572, ROUGE-2: 0.17391304347826086, ROUGE-L: 0.2857142857142857
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year of 2023, Meta spent $3.45 billion on restructuring, with $1.15 billion allocated in Q4 alone.
# ROUGE-1: 0.8292682926829269, ROUGE-2: 0.5641025641025641, ROUGE-L: 0.3414634146341463
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In the fourth quarter of 2023, Meta experienced a 21% increase in ad impressions delivered across its Family of Apps compared to the previous year. Additionally, the average price per ad increased by 2% year-over-year in Q4 2023. For the full year 2023, ad impressions increased by 28% year-over-year, while the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.6923076923076924, ROUGE-2: 0.5294117647058824, ROUGE-L: 0.5961538461538463
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for the first quarter of 2024 is expected to be in the range of $34.5-37 billion. This guidance assumes foreign currency neutrality to year-over-year total revenue growth based on current exchange rates.
# ROUGE-1: 0.5, ROUGE-2: 0.2962962962962963, ROUGE-L: 0.3928571428571429
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: Meta's total costs and expenses for the fourth quarter of 2023 were $23.73 billion, representing an 8% decrease compared to the same period in 2022. For the full year 2023, Meta's total costs and expenses amounted to $88.15 billion, showing a 1% increase from the previous year.
# ROUGE-1: 0.5753424657534247, ROUGE-2: 0.3943661971830986, ROUGE-L: 0.49315068493150693
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: As of December 31, 2023, Meta had $41.86 billion in cash and cash equivalents and $23.54 billion in marketable securities, totaling $65.40 billion in cash, cash equivalents, and marketable securities on hand.
# ROUGE-1: 0.6538461538461539, ROUGE-2: 0.56, ROUGE-L: 0.46153846153846156
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: In 2023, Meta invested in several key areas, including capital expenditures, share repurchases, and restructuring initiatives. The company's capital expenditures, including principal payments on finance leases, amounted to $28.10 billion for the full year. Additionally, Meta repurchased $20.03 billion of its Class A common stock during the year. The company also undertook restructuring measures, including data center initiatives, employee layoffs, and facilities consolidation, with total restructuring charges amounting to $3.45 billion for the year. These investments reflect Meta's strategic focus on enhancing its infrastructure, optimizing its capital structure, and realigning its business operations for greater efficiency.
# ROUGE-1: 0.16260162601626016, ROUGE-2: 0.04958677685950413, ROUGE-L: 0.13008130081300814
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps generated $39.04 billion in revenue, with an income from operations of $21.03 billion. This segment showed strong performance. On the other hand, Reality Labs had revenue of $1.07 billion but incurred a loss from operations of $4.65 billion, indicating a challenging performance for Reality Labs in the same quarter.
# ROUGE-1: 0.6451612903225806, ROUGE-2: 0.3516483516483517, ROUGE-L: 0.5591397849462365
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: In the fourth quarter of 2023, Meta generated $11.50 billion in free cash flow. For the full year 2023, Meta generated $43.01 billion in free cash flow.
# ROUGE-1: 0.7200000000000001, ROUGE-2: 0.6250000000000001, ROUGE-L: 0.56
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta made changes to its stock repurchase program and dividends for 2024. Meta's board of directors declared a cash dividend of $0.50 per share of outstanding common stock, payable on March 26, 2024, to stockholders of record as of February 22, 2024. Additionally, Meta repurchased $6.32 billion of its Class A common stock in the fourth quarter of 2023 and announced a $50 billion increase in its share repurchase authorization. This indicates a significant change in their stock repurchase program for 2024.
# ROUGE-1: 0.42857142857142855, ROUGE-2: 0.32727272727272727, ROUGE-L: 0.30357142857142855
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: For 2024, Meta highlighted several risks in their financial outlook. These risks include the impact of macroeconomic conditions on their business and financial results, potential changes in user retention or growth, reliance on advertising revenue, dependence on data signals and mobile operating systems, changes in third-party policies affecting advertising practices, risks associated with new products and initiatives like the metaverse, emphasis on community growth over short-term financial results, privacy, safety, security, and content review efforts, competition, government actions restricting product access or advertising sales, litigation and government inquiries, privacy, legislative, and regulatory concerns, risks associated with acquisitions, security breaches, managing scale and operations, and market conditions affecting dividend payments. These risks could significantly impact Meta's business and financial performance in 2024.
# ROUGE-1: 0.18666666666666668, ROUGE-2: 0.04054054054054054, ROUGE-L: 0.15999999999999998
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: Meta's revenue growth in Q4 2023 was primarily driven by a 25% increase in advertising revenue, totaling $38.71 billion, compared to the previous year. Additionally, other revenue sources contributed $334 million, showing a significant growth trend. The total revenue for the quarter reached $40.11 billion, reflecting a strong performance in advertising and diversified revenue streams.
# ROUGE-1: 0.3658536585365854, ROUGE-2: 0.19999999999999998, ROUGE-L: 0.3170731707317073
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Throughout 2023, Reality Labs, a segment of Meta, incurred losses with a total of $16.12 billion for the year. This segment faced challenges, as indicated by the negative income from operations. Looking ahead to 2024, Meta expects operating losses for Reality Labs to increase significantly due to ongoing product development efforts in augmented reality/virtual reality and investments to scale the ecosystem. These investments are part of Meta's ambitious long-term AI research and product development efforts, which will require growing infrastructure investments beyond 2024. Despite the current losses, Meta remains committed to advancing its Reality Labs segment and AI initiatives in the coming years.
# ROUGE-1: 0.37241379310344824, ROUGE-2: 0.1118881118881119, ROUGE-L: 0.2482758620689655
#
# Average ROUGE Scores:
# ROUGE-1: 0.5302
# ROUGE-2: 0.3618
# ROUGE-L: 0.4208

# %% [markdown]
# ##prompt8 (optimal prompt and results)

# %%
prompt8 = """
You are a financial analyst tasked with answering questions based on the provided context. Follow these rules:
1. Use the information in the context to provide specific and concise answers.
2. Perform calculations if the question requires them.
3. Don't return special characters
4. If the answer cannot be determined from the context, respond with "I don't know."

### Example Question and Answer
**Question**: How did Meta’s workforce change by the end of 2023?
**Context**: Workforce in 2022: 87,314, Workforce in 2023: 67,317.
**Calculation**: (Old Value − New Value) / Old Value × 100% = (87,314 − 67,317) / 87,314 × 100% ≈ 22.9%.
**Answer**: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.

**Question**: What is the report quarter, and when did it end?
**Context**: The report covers the fourth quarter of 2023, ending December 31, 2023.
**Answer**: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.

### Your Task
Context:
{context}

Question:
{question}

Answer:
"""

# Evaluate
evaluation_output = evaluate_rag_with_prompt(
    chat_model=chat_model,
    retriever=retriever,
    ground_truth=ground_truth,
    prompt_template=prompt8,
    prompt_name="Prompt 8"
)
# Out:
# Individual Results:
# Question: How did Meta’s workforce change by the end of 2023?
# Ground Truth: By the end of 2023, Meta had 67,317 employees. In 2022, Meta had 87,314 employees, so Meta had a 22.9% decrease in 2023 compared to 2022.
# Predicted Answer: By the end of 2023, Meta's workforce was 67,317 employees, which represented a 22% decrease year-over-year.
# ROUGE-1: 0.4897959183673469, ROUGE-2: 0.3404255319148936, ROUGE-L: 0.4897959183673469
#
# Question: What is the report quarter, and when did it end?
# Ground Truth: The reported quarter is the fourth quarter of 2023. The quarter ended on December 31, 2023.
# Predicted Answer: The report quarter is the fourth quarter of 2023, and it ended on December 31, 2023.
# ROUGE-1: 0.875, ROUGE-2: 0.8000000000000002, ROUGE-L: 0.875
#
# Question: What were the key financial highlights this quarter (revenue, gross margin, operating expenses, operating margin, net income, and EPS)?
# Ground Truth: Key financial highlights for Q4 2023 include: Revenue - $40.11 billion, Operating expenses - $23.73 billion, Operating margin - 41%, Net income - $14.02 billion, and EPS - $5.33 (diluted).
# Predicted Answer: The key financial highlights for the quarter ended December 31, 2023, were as follows:
# - Revenue: $40.11 billion
# - Gross Margin: $16.38 billion
# - Operating Expenses: $23.73 billion
# - Operating Margin: 41%
# - Net Income: $14.02 billion
# - Earnings Per Share (EPS): $5.33
# ROUGE-1: 0.7042253521126761, ROUGE-2: 0.6086956521739131, ROUGE-L: 0.7042253521126761
#
# Question: How much did Meta spend on restructuring for the whole year and Q4?
# Ground Truth: Meta spent $1.15 billion on restructuring in Q4 2023 and $3.45 billion for the entire year of 2023.
# Predicted Answer: For the whole year, Meta spent $3.45 billion on restructuring, and for Q4, they spent $1.15 billion.
# ROUGE-1: 0.7692307692307692, ROUGE-2: 0.4864864864864865, ROUGE-L: 0.358974358974359
#
# Question: What happened with Meta’s ad impressions and average price per ad in Q4 and for the whole year?
# Ground Truth: In Q4 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2%. For the whole year 2023, ad impressions increased by 28%, while the average price per ad decreased by 9%.
# Predicted Answer: In Q4 of 2023, ad impressions increased by 21% year-over-year, and the average price per ad increased by 2% year-over-year. For the full year 2023, ad impressions increased by 28% year-over-year, and the average price per ad decreased by 9% year-over-year.
# ROUGE-1: 0.8409090909090908, ROUGE-2: 0.744186046511628, ROUGE-L: 0.8409090909090908
#
# Question: What’s the revenue outlook for Q1 2024?
# Ground Truth: Meta expects Q1 2024 revenue to be in the range of $34.5 billion to $37 billion.
# Predicted Answer: The revenue outlook for Q1 2024 is expected to be in the range of $34.5-37 billion.
# ROUGE-1: 0.7999999999999999, ROUGE-2: 0.5454545454545455, ROUGE-L: 0.6857142857142857
#
# Question: What were Meta’s total costs and expenses for Q4 and the full year 2023?
# Ground Truth: Meta's total costs and expenses were $23.73 billion for Q4 2023 and $88.15 billion for the full year 2023.
# Predicted Answer: Total costs and expenses for Meta in Q4 2023 were $23.73 billion, and for the full year 2023, they were $88.15 billion.
# ROUGE-1: 0.9130434782608695, ROUGE-2: 0.5909090909090909, ROUGE-L: 0.6086956521739131
#
# Question: How much cash and marketable securities did Meta have on hand as of December 31, 2023?
# Ground Truth: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# Predicted Answer: Meta had $65.40 billion in cash, cash equivalents, and marketable securities as of December 31, 2023.
# ROUGE-1: 1.0, ROUGE-2: 1.0, ROUGE-L: 1.0
#
# Question: What were the main areas Meta invested in during 2023?
# Ground Truth: Meta invested significantly in infrastructure, including data centers and AI hardware, as well as in Reality Labs for AR/VR product development.
# Predicted Answer: Meta invested in infrastructure-related costs, payroll expenses, and operating losses for Reality Labs in 2023.
# ROUGE-1: 0.47368421052631576, ROUGE-2: 0.16666666666666666, ROUGE-L: 0.3684210526315789
#
# Question: How did the Family of Apps and Reality Labs perform in Q4 2023?
# Ground Truth: In Q4 2023, Family of Apps revenue was $39.04 billion with operating income of $21.03 billion. Reality Labs revenue was $1.07 billion with an operating loss of $4.65 billion.
# Predicted Answer: In Q4 2023, the Family of Apps generated $39.04 billion in revenue, while Reality Labs generated $1.07 billion in revenue. The Family of Apps had an income from operations of $21.03 billion, while Reality Labs had a loss of $4.65 billion from operations.
# ROUGE-1: 0.7250000000000001, ROUGE-2: 0.41025641025641024, ROUGE-L: 0.5249999999999999
#
# Question: How much free cash flow did Meta generate in Q4 and the full year 2023?
# Ground Truth: Meta generated $11.50 billion in free cash flow for Q4 2023 and $43.01 billion for the full year 2023.
# Predicted Answer: In Q4 2023, Meta generated $11.50 billion in free cash flow. For the full year 2023, Meta generated $43.01 billion in free cash flow.
# ROUGE-1: 0.8085106382978723, ROUGE-2: 0.7111111111111111, ROUGE-L: 0.5957446808510638
#
# Question: Did Meta make any changes to its stock repurchase program or dividends for 2024?
# Ground Truth: Meta announced a $50 billion increase in its stock repurchase authorization and initiated a quarterly dividend of $0.50 per share, payable on March 26, 2024.
# Predicted Answer: Yes, Meta announced a $50 billion increase in its share repurchase authorization and initiated a quarterly cash dividend of $0.50 per share for its outstanding common stock.
# ROUGE-1: 0.7777777777777779, ROUGE-2: 0.6538461538461539, ROUGE-L: 0.7407407407407408
#
# Question: What risks did Meta highlight for 2024?
# Ground Truth: Meta highlighted risks including increased regulatory headwinds in the EU and US, changes in data policies, and escalating infrastructure and payroll costs due to ongoing investments.
# Predicted Answer: For 2024, Meta highlighted risks such as the impact of macroeconomic conditions, user retention or growth, reliance on advertising revenue, changes in third-party policies affecting advertising practices, risks associated with new products and initiatives, emphasis on community growth over short-term financial results, privacy and security concerns, competition, government actions, acquisitions, security breaches, managing operations at scale, and market conditions affecting dividend payments.
# ROUGE-1: 0.22222222222222224, ROUGE-2: 0.06818181818181818, ROUGE-L: 0.2
#
# Question: What drove Meta’s revenue growth in Q4 2023?
# Ground Truth: Revenue growth in Q4 2023 was driven by a 21% increase in ad impressions and a 2% increase in the average price per ad.
# Predicted Answer: The revenue growth in Q4 2023 for Meta was primarily driven by an increase in ad impressions and the average price per ad across their Family of Apps.
# ROUGE-1: 0.6923076923076924, ROUGE-2: 0.52, ROUGE-L: 0.6923076923076924
#
# Question: How did Reality Labs perform throughout 2023, and what’s Meta’s plan for 2024?
# Ground Truth: Reality Labs generated $1.90 billion in revenue in 2023 but incurred a loss of $16.12 billion. For 2024, Meta plans to continue investing in AR/VR product development and scaling its ecosystem, expecting increased operating losses.
# Predicted Answer: Reality Labs had a loss of $16.12 billion in 2023. Meta plans to increase investments in Reality Labs in 2024, expecting operating losses to increase due to ongoing product development efforts in augmented reality/virtual reality and scaling the ecosystem.
# ROUGE-1: 0.6582278481012659, ROUGE-2: 0.36363636363636365, ROUGE-L: 0.4556962025316456
#
# Average ROUGE Scores:
# ROUGE-1: 0.7167
# ROUGE-2: 0.5340
# ROUGE-L: 0.6094

# %% [markdown]
# ##prompt score comparison visualizations

# %%
# Convert summary results to DataFrame
df_summary = pd.DataFrame(evaluation_results_summary)

# Plot 1: Line Graphs for Individual ROUGE Scores
plt.figure(figsize=(12, 24))  # Increased figure height for better spacing between plots

for i, (rouge_type, title) in enumerate(zip(["ROUGE-1", "ROUGE-2", "ROUGE-L"],
                                            ["ROUGE-1 Scores", "ROUGE-2 Scores", "ROUGE-L Scores"])):
    plt.subplot(3, 1, i + 1)  # Change layout to 3 rows, 1 column
    for prompt_name, scores in evaluation_results_detailed.items():
        plt.plot(range(1, len(scores[rouge_type]) + 1), scores[rouge_type], label=prompt_name, marker='o')
    plt.title(title)
    plt.xlabel("Question ID")
    plt.ylabel(rouge_type)
    plt.ylim(0, 1.05)  # Set limits for better visual spacing
    plt.legend(loc="upper right")  # Adjust legend position to avoid overlap
    plt.grid(True)

plt.tight_layout()
plt.savefig("adjusted_individual_rouge_scores.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract prompt names and average ROUGE scores from the summary
prompt_names = [entry["Prompt Name"] for entry in evaluation_results_summary]
average_rouge1 = [entry["Average ROUGE-1"] for entry in evaluation_results_summary]
average_rouge2 = [entry["Average ROUGE-2"] for entry in evaluation_results_summary]
average_rougeL = [entry["Average ROUGE-L"] for entry in evaluation_results_summary]

# Create the line plot
plt.figure(figsize=(12, 8))

# Plot each ROUGE metric
plt.plot(prompt_names, average_rouge1, marker='o', label='Average ROUGE-1', color='blue')
plt.plot(prompt_names, average_rouge2, marker='s', label='Average ROUGE-2', color='orange')
plt.plot(prompt_names, average_rougeL, marker='^', label='Average ROUGE-L', color='green')

# Add values to each point
for i, val in enumerate(average_rouge1):
    plt.text(i, val + 0.005, f"{val:.2f}", ha='center', fontsize=10, color='blue')
for i, val in enumerate(average_rouge2):
    plt.text(i, val + 0.005, f"{val:.2f}", ha='center', fontsize=10, color='orange')
for i, val in enumerate(average_rougeL):
    plt.text(i, val + 0.005, f"{val:.2f}", ha='center', fontsize=10, color='green')

# Add title, labels, and legend
plt.title("Average ROUGE Scores Across Prompts", fontsize=16)
plt.xlabel("Prompt Name", fontsize=14)
plt.ylabel("Average ROUGE Score", fontsize=14)

# Move legend outside the plot
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5), fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)

# Improve layout and show the plot
plt.tight_layout()
plt.savefig("avg_rouge_scores.png")
plt.show()
